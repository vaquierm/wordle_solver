# %% [markdown]
# # Play Wordle with the optimal solver
#
# Here, you can play wordle with the help with the optimal wordle solver to help you out. Before making each guess you can see suggestions of what the best words to use are. You can use this as a practice tool!
#
# ## Load the data
# Run this cell once to load the data

# %%
import numpy as np
from src.data import load_file, load_deep_decision_tree

guesses = load_file("data/wordle_guesses.txt")
answers = load_file("data/wordle_words.txt")
guess_matrix = np.loadtxt("data/guess_matrix.csv")
deep_decision_tree = load_deep_decision_tree("data/deep_decision_tree.pkl")
print("Done loading data")
# Out:
# Done loading data

# %% [markdown]
# ## Play the game!
#
# Run this cell as many times as you want to play a new wordle game!

# %%
from main import human_play_random_word
human_play_random_word(guesses, answers, guess_matrix, deep_decision_tree)
